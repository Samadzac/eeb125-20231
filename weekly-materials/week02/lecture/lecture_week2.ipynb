# %% [markdown]
# # Week 2: Reading a file and handling basic data types
#
# ## EEB125 | W2023
# ## Tomo Parins-Fukuchi

# %% [markdown]
# ### Learning Objectives
# By the end of this lecture, you will be able to
# - work with basic python data types to answer data science questions
# - open and read a data file using Python and Jupyter Notebook
#   * specifically, a dataset capturing occurrences of fossils across Canada
# - parse through the data to extract useful information

# %% [markdown]
# ## Why Python?
# - Python is a nice, general purpose programming language
# - It has excellent support for data science tools
# - It is easy to learn and sets you up for success with other tools

# %% [markdown]
# ## Techniques and concepts
# - Ints vs floats
# - Operators
# - Manipulating strings
# - Variables
# - Lists
# - Dictionaries
# - Looping
# - Tabular data
# - The most fossiliferous(?) Canadian province

# %% [markdown]
# ### Data types
#
# Programming languages specify different types of data
#   - E.g., numbers and letters/words are often represented as different types
#   - In Python, some basic types are:
#     + integers ('ints'): whole numbers (0,1,2)
#     + floats: decimal numbers (e.g., 1.347)
#     + strings: letters and words (e.g., 'horse', 'cat')

# %% [markdown]
# ## Integers
#
# - Round numbers (can be positive or negative)

# %%
type(23)
# Out:
# int

# %% [markdown]
# ## Floats
#
# - Decimal values

# %%
type(23.54321)
# Out:
# float

# %% [markdown]
# ### Operators
#
# - Python has built-in operators for performing operations on ints and floats
# - In addition to `+`, there are others:
#   + `-`,`*`,`**`,`/`,`%`
# - Let's explore what they do:

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# ## Strings
#
# - Words, letters, etc

# %%
type("michael jordan")

# %% [markdown]
# ### Variables
#
# Programming languages store data using _variables_
#   -  A programming variable represents a piece of data
#     + Can generally be any type
#   -  Variables reference value(s) that we assign to them
#   -  We can then manipulate those variables to perform tasks

# %% [markdown]
# ### Example
#
# Create the variable 'x' and assign an integer value to it

# %%
x = 1

# %% [markdown]
# ### Example
#
# `x` is now stored in memory. We will make another and call it 'y'

# %%
x = 1
y = 1

# %% [markdown]
# ### Example
#
# We can now use both of these variables to do some arithmetic:

# %%
x = 1
y = 1
x+y
# Out:
# 2

# %% [markdown]
# ### Example
#
# We can assign pretty much any data type to a variable:

# %%
a = "spongebob "
b = "squarepants"
print(a)
print(b)
# Out:
# spongebob
# squarepants

# %% [markdown]
# ### Example
#
# We also can use some of the same operators on other data types:

# %%
a = "spongebob "
b = "squarepants"
a+b
# Out:
# 'spongebob squarepants'

# %% [markdown]
# ### Reassigning to variables
#
# We can also change the value assigned to a variable:

# %%
b = "loserpants"
print(a+b)
b = "squarepants"
# Out:
# spongebob loserpants

# %%
# can even reassign a variable to itself

b = b
print(a+b)
a = a + b
print(a)
# Out:
# spongebob squarepants
# spongebob squarepants

# %% [markdown]
# ### 'Print' statement
#
# + Often, we may want to see the results of some operation in our notebook or computer terminal
# + We can use the "print" function in python to do this

# %%
print("whoever thought that i would be the greatest growing up?")
# Out:
# whoever thought that i would be the greatest growing up?

# %% [markdown]
# ### Example
#
# Adding two strings basically slams both together. Can we add a string and a number?

# %%
# a+x

# %% [markdown]
# ### Nope!
#
# Interpreting errors is one of the most important parts of programming
#   - This is telling us that we cannot mix these data types when adding

# %% [markdown]
# ### Other errors
#
# - We have to be very careful with what we tell Python. It is very particular.
# - E.g.:

# %%
real = 33
# print(rea)

# %% [markdown]
# ### Other rules for variables
#
# - variable names can contain only letters, numbers, underscores
# - cannot start w a number
# - no spaces
# - don't use python keywords (e.g., `print`)

# %% [markdown]
# ### What else can we do with strings?
#
# - Python has many built-in tools for manipulating strings. Let's explore some:

# %%
# make uppercase 
test = "    what's the deal    "

print(test.upper())
# Out:
#     WHAT'S THE DEAL

# %%
# remove whitespace
test = "    what's the deal    "
print(test.strip())
# Out:
# what's the deal

# %%
# do both
test = "    what's the deal    "
print(test.upper().strip())
# Out:
# WHAT'S THE DEAL

# %%
# do both and reassign to original variable
test = "    what's the deal    "
print(test)
test = test.upper().strip()
print(test)
# Out:
#     what's the deal
# WHAT'S THE DEAL

# %%
# replace part of a string

print(test)
test = test.replace("WHAT'S","THIS IS")
print(test)
# Out:
# WHAT'S THE DEAL
# THIS IS THE DEAL

# %% [markdown]
# ### Converting between types
#
# - In some cases, Python will also allow us to convert between data types

# %%
# we can convert a float to a string:

a = 3.21
a = str(a)
print(a)
# Out:
# 3.21

# %%
# now, if we try to treat it like it is a float, we will get into trouble:

# print(a+3.3)

# %%
# so we can also convert it back:

a = float(a)
print(a)
print(a+3.3)
# Out:
# 3.21
# 6.51

# %% [markdown]
# ### Be careful with types
#
# - This flexibility allows us to be very sloppy with types
# - Not always obvious what type a variable will be
# - Be careful

# %% [markdown]
# ### Containers
#
# - Besides the three we have examined, Python has many other data types
# - Some of these we can refer to as 'containers'
#   + These allow us to store many values within a single variable

# %% [markdown]
# ### Lists
#
# - Lists are a very common python container
# - We can specify a list using square brackets
#
# ```
# my_list = []
# ```
#
# Generates an empty list. We can create a list with things in it:

# %%
emcees = ["tupac","eminem","biggy","weezy"]
print(emcees)
# Out:
# ['tupac', 'eminem', 'biggy', 'weezy']

# %% [markdown]
# ### Lists
#
# We can also add items to an existing list:

# %%
emcees.append("kendrick")
print(emcees)
# Out:
# ['tupac', 'eminem', 'biggy', 'weezy', 'kendrick']

# %% [markdown]
# ### Indexing lists
#
# - We can select individual items from a list by 'indexing' it

# %%
# the first item in python of anything is always accessed as the zeroth item
print(emcees[0])
# Out:
# tupac

# %%
print(emcees[1])
# Out:
# eminem

# %%
# can also index from the other end
print(emcees[-1])
# Out:
# kendrick

# %% [markdown]
# ### Slicing lists
#
# - We can select ranges of items from a list by 'slicing' it

# %%
print(emcees)
print(emcees[1:3])
# Out:
# ['tupac', 'eminem', 'biggy', 'weezy', 'kendrick']
# ['eminem', 'biggy']

# %%
print(emcees)
print(emcees[1:])
# Out:
# ['tupac', 'eminem', 'biggy', 'weezy', 'kendrick']
# ['eminem', 'biggy', 'weezy', 'kendrick']

# %%
print(emcees)
print(emcees[:3])
# Out:
# ['tupac', 'eminem', 'biggy', 'weezy', 'kendrick']
# ['tupac', 'eminem', 'biggy']

# %%
# lists also have tools associated with them
# how many times does "biggy " appear in the list emcees?
print(emcees.count("biggy"))
# Out:
# 1

# %% [markdown]
# ## Creating lists from strings
#
# - Python also has built-in tools for creating a list of smaller strings from a longer string

# %%
emcees_str = "tupac, eminem, biggy, weezy, kendrick"
emcees_ls = emcees_str.split(",")
print(emcees_ls)
# Out:
# ['tupac', ' eminem', ' biggy', ' weezy', ' kendrick']

# %% [markdown]
# ## Creating strings from lists
#
# - We can also join the elements of a list composed of all strings into a larger string

# %%
emcees_str2 = ",".join(emcees_ls)
print(emcees_str2)
# Out:
# tupac, eminem, biggy, weezy, kendrick

# %% [markdown]
# ## Other tools
#
# - Python has many built-in tools for dealing with a variety of data types

# %%
# how long is a list?
print(len(emcees_ls))
# how long is a string?
print(len(emcees_str))
# Out:
# 5
# 37

# %% [markdown]
# ### Reviewing
#
# - Python represents data using different types
#   - ints, floats, strings
# - We can assign data to variables
#   + This allows us to commit it to memory and perform operations later
# - We can store data in 'containers'
#   + We can access data stored in containers by indexing slicing
#   + Containers can also be assigned to variables

# %% [markdown]
# ### Looping
#
# - Much of computing fundamentally involves performing an operation on one piece of data at a time
# - Given a collecton of data, we can examine one item at a time by constructing a **loop**

# %% [markdown]
# ### For loops
#
# - One way of looping over data in Python is by using a 'for loop'

# %%
print(emcees_ls)

for mc in emcees_ls:
    print(mc)
# Out:
# ['tupac', ' eminem', ' biggy', ' weezy', ' kendrick']
# tupac
#  eminem
#  biggy
#  weezy
#  kendrick

# %%
print(emcees_ls)

for mc in emcees_ls:
    print(mc.strip().upper())
# Out:
# ['tupac', ' eminem', ' biggy', ' weezy', ' kendrick']
# TUPAC
# EMINEM
# BIGGY
# WEEZY
# KENDRICK

# %% [markdown]
# ### Tabular data
#
# Much of the data that we will work with is in 'tabular' format
#   - Data contained within rows and columns
#   - Sort of like an Excel spreadsheet

# %% [markdown]
# ### Tabular data
#
# We are often used to seeing data in table form:
#
# | Team          | # of Cups | Last cup | Country      |
# | -----------------------|------------|--------|--------------|
# | Canadiens          | 23          | 1993   | Canada |
# | Maple Leafs           | 13          | 1967  | Canada |
# | Red Wings                | 11          | 2008   | US        |
# | Bruins                   | 6          | 2011      | US|
# | Blackhawks                   | 6          | 2015   | US       |
# | Oilers    | 5          | 1990   | Canada |
# | Penguins               | 5          | 2017 | US      |

# %% [markdown]
# ### Tabular data
#
# - A common way of storing such data for programming is by separating each cell by a pre-specified character. Commas are common:
#
# ```
# team,nCups,lastCup,country
# Canadiens,23,1993,Canada
# MapleLeafs,13,1967,Canada
# RedWings,11,2008,US
# Bruins,6,2011,US
# Blackhawks,6,2015,US
# Oilers,5,1990,Canada
# Penguins,5,2017,US
# ```
#
# - We often refer to this as a "comma-separated values" (csv) file
# - Columns are separated by columns
# - The first line usually contains a guide to the data (the 'header')

# %% [markdown]
# ### Reading and writing data
#
# We often want to work with data stored in external files
#   - This requires us to read files into our active memory so we can perform analyses
#   - We may also want to write new files to save modified data or analyses
#   - We can do this using the `open` function in Python

# %%
open
# Out:
# <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>

# %% [markdown]
# ### 'Calling' (using) a function
#
# To actually use a function, we add parentheses after the function name:
#
# ```open()```

# %%
#open()

# %% [markdown]
# ### Calling `open()`
#
# Functions require 'arguments'-- information we provide that is necessary to perform the function
#   - We are being told that our call needs to specify a `'file'`
#   - We need to tell Python where to find the file we want to open
#
# ![Alt Text](https://media2.giphy.com/media/gsrw6aoAncbKw/giphy.gif?cid=ecf05e47keqvjg4grf3bez5o5trof37x1oh22v51vpx3ghnz&rid=giphy.gif&ct=g)

# %% [markdown]
# ## Today's Data
#
# - We will be using data from the Paleobiology Database (https://paleobiodb.org/#/)
# - Public database of fossil occurrences all over the world
#     - What species did a fossil come from?
#     - Where did it occur?
#     - When did it occur

# %% [markdown]
# ### Reading a file
#
# We can use `open` to read a file that is stored in the directory and save it to a variable:
#
# ```file = open("TESTFILE.csv")```

# %%
file = open("pbdb_data.csv","r")
file
# Out:
# <_io.TextIOWrapper name='pbdb_data.csv' mode='r' encoding='cp1252'>

# %% [markdown]
# ### Reading a file
#
# The information from the file is now assigned to the variable `file`
#   - How can we make this information human-readable?
#
# ```lines = file.readlines()```
#
# Will read all of the lines of text contained within the file and assign them to the variable `lines`

# %%
lines = file.readlines()
lines
# Out:
# ['identified_name,identified_rank,identified_no,accepted_name,accepted_rank,accepted_no,early_interval,max_ma,min_ma,reference_no,cc,state\n',
#  'Bonniopsis sp.,genus,19508,Bonniopsis,genus,19508,Cambrian,541,485.4,61234,CA,Nunavut\n',
#  'Fremontia sp.,genus,155360,Mesonacis,genus,19142,Cambrian,541,485.4,61234,CA,Nunavut\n',
#  'Trilobita indet.,class,19100,Trilobita,class,19100,Cambrian,541,485.4,61234,CA,Nunavut\n',
#  'Paterina sp.,genus,26583,Paterina,genus,26583,Cambrian,541,485.4,61234,CA,Nunavut\n',
#  'Hyolithes sp.,genus,7746,Hyolithes,genus,7746,Cambrian,541,485.4,61234,CA,Nunavut\n',
#  'Bonniopsis sp.,genus,19508,Bonniopsis,genus,19508,Caerfai,530,513,61234,CA,Nunavut\n',
#  'Paedumias sp.,genus,19150,Olenellus (Paedeumias),subgenus,155701,Caerfai,530,513,61234,CA,Nunavut\n',
#  'Trilobita indet.,class,19100,Trilobita,class,19100,Caerfai,530,513,61234,CA,Nunavut\n',
#  'Hyolithes sp.,genus,7746,Hyolithes,genus,7746,Caerfai,530,513,61234,CA,Nunavut\n',
#  'Circotheca sp.,genus,7634,Circotheca,genus,7634,Caerfai,530,513,61234,CA,Nunavut\n',
#  'Acrothele ? sp.,genus,26434,Acrothele,genus,26434,Caerfai,530,513,61234,CA,Nunavut\n',
#  'Agraulos sp.,genus,20257,Agraulos,genus,20257,Cambrian,541,485.4,60927,CA,British Columbia\n',
#  'Bonnia sp.,genus,19506,Bonnia,genus,19506,Cambrian,541,485.4,60927,CA,British Columbia\n',
#  'Crassifimbra sp.,genus,20429,Crassifimbra,genus,20429,Cambrian,541,485.4,60927,CA,British Columbia\n',
#  'Olenellus sp.,genus,19149,Olenellus,genus,19149,Cambrian,541,485.4,60927,CA,British Columbia\n',
#  'Onchocephalus sp.,genus,20769,Onchocephalus,genus,20769,Cambrian,541,485.4,60927,CA,British Columbia\n',
#  'Paedumias sp.,genus,19150,Olenellus (Paedeumias),subgenus,155701,Cambrian,541,485.4,60927,CA,British Columbia\n',
#  'Pagetia sp.,genus,19287,Pagetia,genus,19287,Cambrian,541,485.4,60927,CA,British Columbia\n',
#  'Piaziella sp.,genus,20839,Piaziella,genus,20839,Cambrian,541,485.4,60927,CA,British Columbia\n',
#  'Syspacephalus sp.,genus,20986,Ptychoparella,genus,20902,Cambrian,541,485.4,60927,CA,British Columbia\n',
#  'Zacanthopsis sp.,genus,19719,Zacanthopsis,genus,19719,Cambrian,541,485.4,60927,CA,British Columbia\n',
#  'Inglefieldia ? sp.,genus,20578,Inglefieldia,genus,20578,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Olenellus sp.,genus,19149,Olenellus,genus,19149,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Antagmus sp.,genus,20292,Antagmus,genus,20292,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Bonnia sp.,genus,19506,Bonnia,genus,19506,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Onchocephalus sp.,genus,20769,Onchocephalus,genus,20769,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Acrothele sp.,genus,26434,Acrothele,genus,26434,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Micromitra ? sp.,genus,26582,Micromitra,genus,26582,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Olenellus sequornalus ?,species,19149,Olenellus,genus,19149,Caerfai,530,513,60991,CA,Northwest Territories\n',
#  'Olenellus sp.,genus,19149,Olenellus,genus,19149,Caerfai,530,513,60991,CA,Northwest Territories\n',
#  'Salterella sp.,genus,7470,Salterella,genus,7470,Caerfai,530,513,60991,CA,Northwest Territories\n',
#  'Wanneria sp.,genus,19163,Wanneria,genus,19163,Caerfai,530,513,60991,CA,Northwest Territories\n',
#  'Inglefieldia sp.,genus,20578,Inglefieldia,genus,20578,Dyeran,516,513,60915,CA,British Columbia\n',
#  'Kochiella sp.,genus,20624,Kochiella,genus,20624,Dyeran,516,513,60915,CA,British Columbia\n',
#  'Onchocephalus ? sp.,genus,20769,Onchocephalus,genus,20769,Dyeran,516,513,60915,CA,British Columbia\n',
#  'Plagiura sp.,genus,21999,Plagiura,genus,21999,Dyeran,516,513,60915,CA,British Columbia\n',
#  'Plagiurella sp.,genus,155755,Plagiura,genus,21999,Dyeran,516,513,60915,CA,British Columbia\n',
#  'Poulsenia ? sp.,genus,20861,Poulsenia,genus,20861,Dyeran,516,513,60915,CA,British Columbia\n',
#  'Proliostracus sp.,genus,20872,Proliostracus,genus,20872,Dyeran,516,513,60915,CA,British Columbia\n',
#  'Prozacanthoides sp.,genus,19671,Prozacanthoides,genus,19671,Dyeran,516,513,60915,CA,British Columbia\n',
#  'Ptychoparella sp.,genus,20902,Ptychoparella,genus,20902,Dyeran,516,513,60915,CA,British Columbia\n',
#  'Zacanthopsis sp.,genus,19719,Zacanthopsis,genus,19719,Dyeran,516,513,60915,CA,British Columbia\n',
#  'Hyolithes sp.,genus,7746,Hyolithes,genus,7746,Dyeran,516,513,60915,CA,British Columbia\n',
#  'Inarticulata indet.,order,26587,Brachiopoda,phylum,26322,Dyeran,516,513,60915,CA,British Columbia\n',
#  'Hyolithes sp.,genus,7746,Hyolithes,genus,7746,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Protoconchioides ? rasettii,species,65879,Protoconchioides rasettii,species,65879,Delamaran,513,505,11618,CA,British Columbia\n',
#  'Acrotreta sp.,genus,26436,Acrotreta,genus,26436,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Acrothele sp.,genus,26434,Acrothele,genus,26434,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Dictyonina sp.,genus,26577,Dictyonina,genus,26577,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Paterina ? sp.,genus,26583,Paterina,genus,26583,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Amecephalus sp.,genus,20273,Amecephalus,genus,20273,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Chancia sp.,genus,20399,Chancia,genus,20399,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Ogygopsis sp.,genus,19628,Ogygopsis,genus,19628,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Oryctocephalus sp.,genus,19639,Oryctocephalus,genus,19639,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Poliella sp.,genus,19659,Poliella,genus,19659,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Stephenaspis sp.,genus,19692,Stephenaspis,genus,19692,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Syspacephalus sp.,genus,20986,Ptychoparella,genus,20902,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Wenkchemnia sp.,genus,19716,Wenkchemnia,genus,19716,Delamaran,513,505,32149,CA,British Columbia\n',
#  'Albertella sp.,genus,19475,Albertella,genus,19475,Merioneth,501,485.4,60915,CA,British Columbia\n',
#  'Amecephalus sp.,genus,20273,Amecephalus,genus,20273,Merioneth,501,485.4,60915,CA,British Columbia\n',
#  'Kochina sp.,genus,20625,Kochina,genus,20625,Merioneth,501,485.4,60915,CA,British Columbia\n',
#  'Poliella sp.,genus,19659,Poliella,genus,19659,Merioneth,501,485.4,60915,CA,British Columbia\n',
#  'Ptarmingia sp.,genus,396935,Ptarmingia,genus,396935,Merioneth,501,485.4,60915,CA,British Columbia\n',
#  'Vanuxemella sp.,genus,19714,Vanuxemella,genus,19714,Merioneth,501,485.4,60915,CA,British Columbia\n',
#  'Mexicella sp.,genus,20720,Mexicella,genus,20720,Merioneth,501,485.4,60915,CA,British Columbia\n',
#  'Hyolithes sp.,genus,7746,Hyolithes,genus,7746,Merioneth,501,485.4,60915,CA,British Columbia\n',
#  'Acrothele sp.,genus,26434,Acrothele,genus,26434,Merioneth,501,485.4,60915,CA,British Columbia\n',
#  'Obolus sp.,genus,26383,Obolus,genus,26383,Merioneth,501,485.4,60915,CA,British Columbia\n',
#  'Wimanella sp.,genus,27045,Wimanella,genus,27045,Merioneth,501,485.4,60915,CA,British Columbia\n',
#  'Paterina sp.,genus,26583,Paterina,genus,26583,Merioneth,501,485.4,60915,CA,British Columbia\n',
#  'Bathyuriscidella sp.,genus,19498,Bathyuriscidella,genus,19498,St Davids,513,501,60991,CA,Northwest Territories\n',
#  'Bathyuriscus adaeus,species,396062,Bathyuriscus adaeus,species,396062,St Davids,513,501,60991,CA,Northwest Territories\n',
#  'Elrathina spinifera,species,20483,Ptychoparella,genus,20902,St Davids,513,501,60991,CA,Northwest Territories\n',
#  'Oryctocephalus sp.,genus,19639,Oryctocephalus,genus,19639,St Davids,513,501,60991,CA,Northwest Territories\n',
#  'Pagetia sp.,genus,19287,Pagetia,genus,19287,St Davids,513,501,60991,CA,Northwest Territories\n',
#  'Peronopsis columbiensis,species,19293,Peronopsis,genus,19293,St Davids,513,501,60991,CA,Northwest Territories\n',
#  'Zacanthoides sp.,genus,19718,Zacanthoides,genus,19718,St Davids,513,501,60991,CA,Northwest Territories\n',
#  'Alokistocare sp.,genus,20267,Alokistocare,genus,20267,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Athabaskia ? sp.,genus,19493,Athabaskia,genus,19493,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Bathyuriscus sp.,genus,19500,Bathyuriscus,genus,19500,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Chancia sp.,genus,20399,Chancia,genus,20399,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Elrathina sp.,genus,20483,Ptychoparella,genus,20902,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Olenoides sp.,genus,19629,Olenoides,genus,19629,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Pachyaspis sp.,genus,20782,Pachyaspis,genus,20782,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Pagetia sp.,genus,19287,Pagetia,genus,19287,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Peronopsis sp.,genus,19293,Peronopsis,genus,19293,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Solenopleurella sp.,genus,20966,Solenopleurella,genus,20966,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Kootenia sp.,genus,19595,Kootenia,genus,134224,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Tonkinella sp.,genus,19708,Tonkinella,genus,19708,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Zacanthoides sp.,genus,19718,Zacanthoides,genus,19718,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Paterina sp.,genus,26583,Paterina,genus,26583,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Iphidella sp.,genus,234960,Micromitra,genus,26582,Merioneth,501,485.4,60927,CA,Alberta-British Columbia\n',
#  'Elrathina sp.,genus,20483,Ptychoparella,genus,20902,St Davids,513,501,61174,CA,British Columbia\n',
#  'Elrathia permulta,species,435932,Elrathia permulta,species,435931,St Davids,513,501,61174,CA,British Columbia\n',
#  'Olenoides serratus,species,461550,Olenoides serratus,species,461549,St Davids,513,501,61174,CA,British Columbia\n',
#  'Kootenia burgessensis,species,19595,Kootenia,genus,134224,St Davids,513,501,61174,CA,British Columbia\n',
#  'Ptychagnostus burgessensis,species,19306,Ptychagnostus,genus,19306,St Davids,513,501,61174,CA,British Columbia\n',
#  'Pagetia booti,species,19287,Pagetia,genus,19287,St Davids,513,501,61174,CA,British Columbia\n',
#  'Canadaspis sp.,genus,22218,Canadaspis,genus,22218,St Davids,513,501,61174,CA,British Columbia\n',
#  'Perspicaris sp.,genus,22219,Perspicaris,genus,22219,St Davids,513,501,61174,CA,British Columbia\n',
#  'Plenocaris sp.,genus,22108,Plenocaris,genus,22108,St Davids,513,501,61174,CA,British Columbia\n',
#  'Anomalocaris sp.,genus,7370,Anomalocaris,genus,7370,St Davids,513,501,61174,CA,British Columbia\n',
#  'Paterina sp.,genus,26583,Paterina,genus,26583,St Davids,513,501,61174,CA,British Columbia\n',
#  'Dictyonina sp.,genus,26577,Dictyonina,genus,26577,St Davids,513,501,61174,CA,British Columbia\n',
#  'Micromitra sp.,genus,26582,Micromitra,genus,26582,St Davids,513,501,61174,CA,British Columbia\n',
#  'Echmatocrinus sp.,genus,31592,Echmatocrinus,genus,31592,St Davids,513,501,61174,CA,British Columbia\n',
#  'Gogia sp.,genus,31066,Gogia,genus,31066,St Davids,513,501,61174,CA,British Columbia\n',
#  'Protoconchioides ? rasettii ?,species,65879,Protoconchioides rasettii,species,65879,St Davids,513,501,11618,CA,British Columbia\n',
#  'Hyolithes sp.,genus,7746,Hyolithes,genus,7746,St Davids,513,501,61174,CA,British Columbia\n',
#  'Chaunograptus sp.,genus,33800,Chaunograptus,genus,33800,St Davids,513,501,61174,CA,British Columbia\n',
#  'Hazelia sp.,genus,2926,Hazelia,genus,2926,St Davids,513,501,61174,CA,British Columbia\n',
#  'Protospongia sp.,genus,4131,Protospongia,genus,4131,St Davids,513,501,61174,CA,British Columbia\n',
#  'Eiffelia sp.,genus,3611,Eiffelia,genus,3611,St Davids,513,501,61174,CA,British Columbia\n',
#  'Chancelloria sp.,genus,7321,Chancelloria,genus,7321,St Davids,513,501,61174,CA,British Columbia\n',
#  'Ogygopsis klotzi,species,460262,Ogygopsis klotzi,species,460261,St Davids,513,501,61174,CA,British Columbia\n',
#  'Zacanthoides nomengei,species,19718,Zacanthoides,genus,19718,St Davids,513,501,61174,CA,British Columbia\n',
#  'Bathyuriscus sp.,genus,19500,Bathyuriscus,genus,19500,St Davids,513,501,61174,CA,British Columbia\n',
#  'Parkaspis decamera,species,19653,Parkaspis,genus,19653,St Davids,513,501,61174,CA,British Columbia\n',
#  'Pachyaspis sp.,genus,20782,Pachyaspis,genus,20782,St Davids,513,501,61174,CA,British Columbia\n',
#  'Peronopsis sp.,genus,19293,Peronopsis,genus,19293,St Davids,513,501,61174,CA,British Columbia\n',
#  'Ehmaniella sp.,genus,20471,Ehmaniella,genus,20471,St Davids,513,501,61174,CA,British Columbia\n',
#  'Chancia palliseri,species,461613,Chanciaopsis palliseri,species,461613,St Davids,513,501,61174,CA,British Columbia\n',
#  'Oryctocephalus sp.,genus,19639,Oryctocephalus,genus,19639,St Davids,513,501,61174,CA,British Columbia\n',
#  'Nisusia sp.,genus,26877,Nisusia,genus,26877,St Davids,513,501,61174,CA,British Columbia\n',
#  'Solenopleurella sp.,genus,20966,Solenopleurella,genus,20966,St Davids,513,501,61174,CA,British Columbia\n',
#  'Lingulella sp.,genus,26371,Lingulella,genus,26371,St Davids,513,501,61174,CA,British Columbia\n',
#  'Triograptus sp.,genus,33573,Triograptus,genus,33573,Arenig,478.6,466,60919,CA,Yukon\n',
#  'Bryograptus sp.,genus,33544,Bryograptus,genus,33544,Arenig,478.6,466,60919,CA,Yukon\n',
#  'Didymograptus cf. primigenius,species,378281,Anisograptus matanensis,species,378278,Arenig,478.6,466,60919,CA,Yukon\n',
#  'Lingulepis ? sp.,genus,26373,Lingulepis,genus,26373,Arenig,478.6,466,60919,CA,Yukon\n',
#  'Hyolithes sp.,genus,7746,Hyolithes,genus,7746,Arenig,478.6,466,60919,CA,Yukon\n',
#  'Phyllocarida indet.,subclass,22258,Phyllocarida,subclass,22258,Arenig,478.6,466,60919,CA,Yukon\n',
#  'Hesperonomia sp.,genus,26798,Hesperonomia,genus,26798,Canadian,485.4,468.1,7070,CA,Northwest Territories\n',
#  'Diparelasma sp.,genus,26738,Diparelasma,genus,26738,Canadian,485.4,468.1,7070,CA,Northwest Territories\n',
#  'Syntrophopsis sp.,genus,28316,Syntrophopsis,genus,28316,Canadian,485.4,468.1,7070,CA,Northwest Territories\n',
#  'Tritoechia sp.,genus,27029,Tritoechia,genus,27029,Canadian,485.4,468.1,7070,CA,Northwest Territories\n',
#  'Hesperonomiella ? sp.,genus,26799,Hesperonomiella,genus,26799,Canadian,485.4,468.1,7070,CA,Northwest Territories\n',
#  'Carolinites ? sp.,genus,21111,Carolinites,genus,21111,Canadian,485.4,468.1,7070,CA,Northwest Territories\n',
#  'Goniotelina sp.,genus,21188,Acidiphorus,genus,21064,Canadian,485.4,468.1,7070,CA,Northwest Territories\n',
#  'Pseudocybele sp.,genus,21739,Pseudocybele,genus,21739,Canadian,485.4,468.1,7070,CA,Northwest Territories\n',
#  'Orthida indet.,order,26648,Orthida,order,26648,Llanvirn,466,460.9,61157,CA,Yukon\n',
#  'Inarticulata indet.,order,26587,Brachiopoda,phylum,26322,Llanvirn,466,460.9,61157,CA,Yukon\n',
#  'Peraspis sp.,genus,20828,Peraspis,genus,20828,Llanvirn,466,460.9,61157,CA,Yukon\n',
#  'Protocalymene sp.,genus,21732,Protocalymene,genus,21732,Llanvirn,466,460.9,61157,CA,Yukon\n',
#  'Globampyx sp.,genus,19967,Globampyx,genus,19967,Llanvirn,466,460.9,61157,CA,Yukon\n',
#  'Arthrorhachis sp.,genus,19186,Arthrorhachis,genus,19186,Llanvirn,466,460.9,61157,CA,Yukon\n',
#  'Nileus sp.,genus,20075,Nileus,genus,20075,Llanvirn,466,460.9,61157,CA,Yukon\n',
#  'Cybelurus sp.,genus,21520,Cybelurus,genus,21520,Llanvirn,466,460.9,61157,CA,Yukon\n',
#  'Blosyropsis sp.,genus,20356,Blosyropsis,genus,20356,Llanvirn,466,460.9,61157,CA,Yukon\n',
#  'Niobe sp.,genus,20077,Niobe,genus,20077,Llanvirn,466,460.9,61157,CA,Yukon\n',
#  'Illaenus sp.,genus,19582,Illaenus,genus,19582,Llanvirn,466,460.9,61157,CA,Yukon\n',
#  'Phylloporina sp.,genus,25611,Phylloporina,genus,25611,Chazyan,468.1,460.9,60945,CA,Quebec\n',
#  'Camerella sp.,genus,28179,Camerella,genus,28179,Chazyan,468.1,460.9,60945,CA,Quebec\n',
#  'Dactylogonia sp.,genus,27276,Dactylogonia,genus,27276,Chazyan,468.1,460.9,60945,CA,Quebec\n',
#  '
Llandeilo,466,449.5,61158,CA,Northwest Territories\n',
#  'Diplograptus sp.,genus,33660,Diplograptus,genus,33660,Llandeilo,466,449.5,61158,CA,Northwest Territories\n',
#  'Amplexograptus ? sp.,genus,33615,Amplexograptus,genus,33615,Darriwilian,467.3,453,60991,CA,Northwest Terrorities\n',
#  'Bryozoa indet.,phylum,24773,Bryozoa,phylum,24773,Darriwilian,467.3,453,60991,CA,Northwest Terrorities\n',
#  'Sowerbyella ? sp.,genus,27972,Sowerbyella,genus,27972,Darriwilian,467.3,453,60991,CA,Northwest Terrorities\n',
#  'Rafinesquinidae indet.,family,84998,Rafinesquinidae,family,84998,Darriwilian,467.3,453,60991,CA,Northwest Terrorities\n',
#  'Orthidae indet.,family,82652,Orthidae,family,82652,Darriwilian,467.3,453,60991,CA,Northwest Terrorities\n',
#  'Inarticulata indet.,order,26587,Brachiopoda,phylum,26322,Darriwilian,467.3,453,60991,CA,Northwest Terrorities\n',
#  'Cnemidopyge sp.,genus,19914,Cnemidopyge,genus,19914,Darriwilian,467.3,453,60991,CA,Northwest Terrorities\n',
#  'Geragnostus sp.,genus,19228,Geragnostus,genus,19228,Darriwilian,467.3,453,60991,CA,Northwest Terrorities\n',
#  'Lonchodomas ? sp.,genus,20035,Lonchodomas,genus,20035,Darriwilian,467.3,453,60991,CA,Northwest Terrorities\n',
#  'Platycalymene sp.,genus,21713,Platycalymene,genus,21713,Darriwilian,467.3,453,60991,CA,Northwest Terrorities\n',
#  'Staurocephalus sp.,genus,21782,Staurocephalus,genus,21782,Darriwilian,467.3,453,60991,CA,Northwest Terrorities\n',
#  'Asaphidae indet.,family,82596,Asaphidae,family,82596,Darriwilian,467.3,453,60991,CA,Northwest Terrorities\n',
#  'Encrinuridae indet.,family,97159,Encrinuridae,family,97159,Darriwilian,467.3,453,60991,CA,Northwest Terrorities\n',
#  'Lingulella ? sp.,genus,26371,Lingulella,genus,26371,Middle Ordovician,470,458.4,60945,CA,Quebec\n',
#  'Rostricellula sp.,genus,28877,Rostricellula,genus,28877,Middle Ordovician,470,458.4,60945,CA,Quebec\n',
#  'Ctenodonta sp.,genus,16029,Ctenodonta,genus,16029,Middle Ordovician,470,458.4,60945,CA,Quebec\n',
#  'Modiolopsis sp.,genus,17148,Modiolopsis,genus,17148,Middle Ordovician,470,458.4,60945,CA,Quebec\n',
#  'Leperditella sp.,genus,23317,Leperditella,genus,23317,Middle Ordovician,470,458.4,60945,CA,Quebec\n',
#  'Apatochilina sp.,genus,22999,Apatochilina,genus,22999,Middle Ordovician,470,458.4,60945,CA,Quebec\n',
#  'Briartina sp.,genus,22929,Briartina,genus,22929,Middle Ordovician,470,458.4,60945,CA,Quebec\n',
#  'Michelinoceras sp.,genus,12542,Michelinoceras,genus,12542,Middle Ordovician,470,458.4,60945,CA,Quebec\n',
#  'Archaeogastropoda indet.,order,8515,Archaeogastropoda,order,8515,Middle Ordovician,470,458.4,60945,CA,Quebec\n',
#  'Hallopora sp.,genus,25275,Hallopora,genus,25275,Caradoc,460.9,449.5,60947,CA,Ontario\n',
#  'Mesotrypa sp.,genus,25303,Mesotrypa,genus,25303,Caradoc,460.9,449.5,60947,CA,Ontario\n',
#  'Pachydictya sp.,genus,25451,Pachydictya,genus,25451,Caradoc,460.9,449.5,60947,CA,Ontario\n',
#  'Prasopora sp.,genus,25340,Prasopora,genus,25340,Caradoc,460.9,449.5,60947,CA,Ontario\n',
#  'Rhinidictya sp.,genus,139262,Rhinidictya,genus,139262,Caradoc,460.9,449.5,60947,CA,Ontario\n',
#  'Stictoporella sp.,genus,25488,Stictoporella,genus,25488,Caradoc,460.9,449.5,60947,CA,Ontario\n',
#  '
Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Plectodonta sp.,genus,27793,Plectodonta,genus,27793,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Plectatrypa sp.,genus,29914,Plectatrypa,genus,29914,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Parmorthis sp.,genus,26916,Resserella,genus,26970,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Rhipidomella sp.,genus,26974,Rhipidomella,genus,26974,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Rhynchonella sp.,genus,28856,Rhynchonella,genus,28856,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Rhynchotreta sp.,genus,28864,Rhynchotreta,genus,28864,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Schizotreta sp.,genus,26556,Schizotreta,genus,26556,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Strophonella sp.,genus,28018,Strophonella,genus,28018,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Whitfieldella sp.,genus,29741,Whitfieldella,genus,29741,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Leperditia sp.,genus,22944,Leperditia,genus,22944,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Bythocypris sp.,genus,23957,Bythocypris,genus,23957,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Calymene sp.,genus,21478,Calymene,genus,21478,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Cyphaspis sp.,genus,21134,Cyphaspis,genus,21134,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Dalmanites sp.,genus,21523,Dalmanites,genus,21523,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Encrinurus sp.,genus,21560,Encrinurus,genus,21560,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Tentaculites sp.,genus,8234,Tentaculites,genus,8234,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Conularia sp.,genus,4568,Conularia,genus,4568,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Ildraites sp.,genus,7114,Ildraites,genus,7114,Llandovery,443.4,433.4,61474,CA,Ontario\n',
#  'Leptaena rhomboidalis,species,307326,Leptaena rhomboidalis,species,307326,Rhuddanian,443.4,440.8,13433,CA,Ontario\n',
#  'Bellerophon sp.,genus,8311,Bellerophon,genus,8311,Rhuddanian,443.4,440.8,13433,CA,Ontario\n',
#  'Holopea sp.,genus,8461,Holopea,genus,8461,Rhuddanian,443.4,440.8,13433,CA,Ontario\n',
#  'Monograptus sp.,genus,33698,Monograptus,genus,33698,Lochkovian,419.2,407.6,60988,CA,Northwest Territories and Yukon\n',
#  'Linograptus sp.,genus,33689,Linograptus,genus,33689,Lochkovian,419.2,407.6,60988,CA,Northwest Territories and Yukon\n',
#  'Nowakia sp.,genus,8258,Nowakia,genus,8258,Lochkovian,419.2,407.6,60988,CA,Northwest Territories and Yukon\n',
#  'Warburgella sp.,genus,21405,Warburgella,genus,21405,Lochkovian,419.2,407.6,60988,CA,Northwest Territories and Yukon\n',
#  'Proetida indet.,order,21062,Proetida,order,21062,Lochkovian,419.2,407.6,60988,CA,Northwest Territories and Yukon\n',
#  'Phacopida ? indet.,order,21421,Phacopida,order,21421,Lochkovian,419.2,407.6,60988,CA,Northwest Territories and Yukon\n',
#  'Praecardiorda (Buchiola) indet.,subgenus,136813,Buchiola (Megabuchiola),subgenus,136813,Lochkovian,419.2,407.6,60988,CA,Northwest Territories and Yukon\n',
#  'Porifera indet.,phylum,2894,Porifera,phylum,2894,Lochkovian,419.2,407.6,60988,CA,Northwest Territories and Yukon\n',
#  'Strophomenida indet.,order,27053,Strophomenida,order,27053,Lochkovian,419.2,407.6,60988,CA,Northwest Territories and Yukon\n',
#  'Pterygotus sp.,genus,18992,Pterygotus,genus,18992,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Phacops sp.,genus,21701,Phacops,genus,21701,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Dalmanites sp.,genus,21523,Dalmanites,genus,21523,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Bronteus sp.,genus,20372,Scutellum,genus,19684,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Orthoceras sp.,genus,12557,Orthoceras,genus,12557,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Kionoceras sp.,genus,12529,Kionoceras,genus,12529,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Gastropoda indet.,class,8304,Gastropoda,class,8304,Lochkovian,419.2,410.8,9042,CA,New Brunswick\n',
#  'Coelidium sp.,genus,70970,Coelocaulus,genus,8684,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Melissosoa sp.,genus,71032,Michelia,genus,8977,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Platyceras sp.,genus,9117,Platyceras,genus,9117,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Euomphalidae sp.,genus,70088,Euomphalidae,family,70088,Lochkovian,419.2,410.8,9042,CA,New Brunswick\n',
#  'Pterinopecten sp.,genus,16985,Pterinopecten,genus,16985,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Pterinea sp.,genus,16982,Pterinea,genus,16982,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Pteronitella sp.,genus,16988,Pteronitella,genus,16988,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Mytilarca sp.,genus,16833,Mytilarca,genus,16833,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Modiomorpha sp.,genus,17149,Modiomorpha,genus,17149,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Sphenotus sp.,genus,63203,Sanguinolites,genus,18822,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Carydium sp.,genus,17115,Carydium,genus,17115,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Cypricardella sp.,genus,17557,Cypricardella,genus,17557,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Macrodus sp.,genus,0,,,,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Janeia sp.,genus,16154,Janeia,genus,16154,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Nuculites sp.,genus,16085,Nuculites,genus,16085,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Nuculana sp.,genus,16083,Nuculana,genus,16083,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Conocardioidea indet.,superfamily,58093,Conocardioidea,superfamily,58093,Lochkovian,419.2,410.8,9042,CA,New Brunswick\n',
#  'Rensselaeria sp.,genus,30493,Rensselaeria,genus,30493,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Camarotoechia sp.,genus,28431,Camarotoechia,genus,28431,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Spirifer sp.,genus,29638,Spirifer,genus,29638,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Meristella sp.,genus,29427,Meristella,genus,29427,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Atrypa sp.,genus,29779,Atrypa,genus,29779,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Leptostrophia sp.,genus,27561,Leptostrophia,genus,27561,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Orthotetes sp.,genus,27714,Orthotetes,genus,27714,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Orbiculoidea sp.,genus,26527,Orbiculoidea,genus,26527,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Crania sp.,genus,26603,Crania,genus,26603,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Pholidops sp.,genus,310014,Craniops,genus,26589,Lochkovian,419.2,410.8,26349,CA,New Brunswick\n',
#  'Favosites sp.,genus,4880,Favosites,genus,4880,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Halysites sp.,genus,4897,Halysites,genus,4897,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Zaphrentis sp.,genus,111319,Zaphrenthis,genus,6080,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Dictyonema sp.,genus,33553,Dictyonema,genus,33553,Lochkovian,419.2,410.8,15806,CA,New Brunswick\n',
#  'Phacops sp.,genus,21701,Phacops,genus,21701,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Dalmanites sp.,genus,21523,Dalmanites,genus,21523,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Kionoceras sp.,genus,12529,Kionoceras,genus,12529,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Lophospiridae ? indet.,family,56479,Lophospiridae,family,56479,Pragian,410.8,407.6,9042,CA,Quebec\n',
#  'Stenoloron ? sp.,genus,9268,Stenoloron,genus,122080,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Actinopteria sp.,genus,16442,Actinopteria,genus,16442,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Modiomorpha sp.,genus,17149,Modiomorpha,genus,17149,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Goniophora sp.,genus,17135,Goniophora,genus,17135,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Leptodomus sp.,genus,204748,Leptodomus,genus,204748,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Camarotoechia sp.,genus,28431,Camarotoechia,genus,28431,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Uncinulus sp.,genus,29000,Uncinulus,genus,29000,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Atrypina sp.,genus,29783,Atrypina,genus,29783,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Leptostrophia sp.,genus,27561,Leptostrophia,genus,27561,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Leptaena sp.,genus,27544,Leptaena,genus,27544,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Strophonella sp.,genus,28018,Strophonella,genus,28018,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Orthostrophia sp.,genus,26901,Orthostrophia,genus,26901,Pragian,410.8,407.6,15806,CA,Quebec\n',
#  'Dawsonelloides canadensis,species,27285,Dawsonelloides,genus,27285,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Acrospirifer murchisoni,species,311275,Acrospirifer murchisoni,species,311274,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Synphoria sopita,species,21791,Synphoria,genus,21791,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Beachia thunei,species,30047,Beachia,genus,30047,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Leptostrophia sp.,genus,27561,Leptostrophia,genus,27561,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Tentaculites leclercqi,species,8234,Tentaculites,genus,8234,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Meristella champlaini,species,29427,Meristella,genus,29427,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Bivalvia indet.,class,16005,Bivalvia,class,16005,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Salopina ? sp.,genus,26983,Salopina,genus,26983,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Leptocoelia flabellites,species,29870,Leptocoelia,genus,29870,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Discomyorthis musculosa,species,311038,Discomyorthis musculosa,species,311035,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Plicoplasia plicata,species,29534,Plicoplasia,genus,29534,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Cyrtina rostrata,species,29207,Cyrtina,genus,29207,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Anchiopsis anchiops,species,426095,Anchiopsis anchiops,species,426091,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Strophomenida indet.,order,27053,Strophomenida,order,27053,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Orbiculoidea montis,species,26527,Orbiculoidea,genus,26527,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Coelospira ? sp.,genus,29811,Coelospira,genus,29811,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Bryozoa indet.,phylum,24773,Bryozoa,phylum,24773,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Archaeogastropoda ? indet.,order,8515,Archaeogastropoda,order,8515,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Orthida indet.,order,26648,Orthida,order,26648,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Ostracoda indet.,class,22826,Ostracoda,class,22826,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Synphoroides sp.,genus,21792,Synphoroides,genus,21792,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Conularia sp.,genus,4568,Conularia,genus,4568,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Acrospirifer murchisoni,species,311275,Acrospirifer murchisoni,species,311274,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Meristella champlaini,species,29427,Meristella,genus,29427,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Discomyorthis musculosa,species,311038,Discomyorthis musculosa,species,311035,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Pleiopleurina pleiopleura,species,28797,Pleiopleurina,genus,28797,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Costispirifer arenosus,species,29189,Costispirifer,genus,29189,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Leptostrophia sp.,genus,27561,Leptostrophia,genus,27561,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Beachia thunei,species,30047,Beachia,genus,30047,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  'Strophodonta sp.,genus,28016,Strophomena (Strophodonta),subgenus,110290,Pragian,410.8,407.6,36816,CA,Quebec\n',
#  ...]

# %% [markdown]
# ### Reading a file
#
# We now have our information in a way we can interpret
#   - The lines of the file are stored as strings contained within a list
#   - The first line is a "header"-- it describes the data
#   - How can we examine this header?

# %%
header = lines[0]
print(header)
# Out:
# identified_name,identified_rank,identified_no,accepted_name,accepted_rank,accepted_no,early_interval,max_ma,min_ma,reference_no,cc,state

# %%
# assign the rest of the data to a variable called data
data = lines[1:]

# %% [markdown]
# ### Which Canadian province is the most fossil-rich?
#
# - We have the lines of our data stored in a list
# - That means we can loop over the lines and extract data one line at a time

# %%
# create an empty dictionary that we will populate with data
province_recs = []

for line in lines[1:]:
    line_dat = line.strip().split(",")
    province = line_dat[-1].strip()
    province_recs.append(province)

# %% [markdown]
# ## Quiz
#
# - What type is `province_recs`?

# %% [markdown]
# - What information does it contain from our data file?

# %%
print(province_recs)
# Out:
# ['Nunavut', 'Nunavut', 'Nunavut', 'Nunavut', 'Nunavut', 'Nunavut', 'Nunavut', 'Nunavut', 'Nunavut', 'Nunavut', 'Nunavut', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'Northwest Territories', 'Northwest Territories', 'Northwest Territories', 'Northwest Territories', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'Northwest Territories', 'Northwest Territories', 'Northwest Territories', 'Northwest Territories', 'Northwest Territories', 'Northwest Territories', 'Northwest Territories', 'Alberta-British Columbia', 'Alberta-British Columbia', 'Alberta-British Columbia', 'Alberta-British Columbia', 'Alberta-British Columbia', 'Alberta-British Columbia', 'Alberta-British Columbia', 'Alberta-British Columbia', 'Alberta-British Columbia', 'Alberta-British Columbia', 'Alberta-British Columbia', 'Alberta-British Columbia', 'Alberta-British Columbia', 'Alberta-British Columbia', 'Alberta-British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'British Columbia', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Northwest Territories', 'Northwest Territories', 'Northwest Territories', 'Northwest Territories', 'Northwest Territories', 'Northwest Territories', 'Northwest Territories', 'Northwest Territories', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Yukon', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec', 'Quebec',  ...

# %% [markdown]
# ## One at a time
#
# - We could look up the number of fossils one province/territory at a time
# - Count the number of times that province/territory occurs in the list using `.count()`

# %%
province = "Ontario"
province_recs.count(province)
# Out:
# 4786

# %% [markdown]
# ## Brainstorm
#
# - How else might we do this? Is there a more efficient way to get results for every province?

# %%
province_ls = ["Ontario","British Columbia","Alberta","Saskatchewan","Manitoba","Newfoundland and Labrador","Northwest Territories","Yukon","Prince Edward Island","Nunavut","Nova Scotia","Quebec","New Brunswick"]
print(province_ls)
# Out:
# ['Ontario', 'British Columbia', 'Alberta', 'Saskatchewan', 'Manitoba', 'Newfoundland and Labrador', 'Northwest Territories', 'Yukon', 'Prince Edward Island', 'Nunavut', 'Nova Scotia', 'Quebec', 'New Brunswick']

# %%
for i in province_ls:
    print(i,province_recs.count(i))
# Out:
# Ontario 4786
# British Columbia 20473
# Alberta 10578
# Saskatchewan 1756
# Manitoba 2432
# Newfoundland and Labrador 2679
# Northwest Territories 8736
# Yukon 3692
# Prince Edward Island 44
# Nunavut 6827
# Nova Scotia 1655
# Quebec 7072
# New Brunswick 841

# %% [markdown]
# ## END :)
